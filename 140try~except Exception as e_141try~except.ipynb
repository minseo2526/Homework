# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/140try~except%20Exception%20as%20e_141try~except.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intList=range(10)
idx=10
try:
  print(intList[idx])
except Exception as e:
  exceptionClass=e.__class__.__name__
  exceptionDetail=e.__str__()
  print(f'예외종류:{exceptionClass},예외내용:{exceptionDetail}')
# Out:
# 예외종류:IndexError,예외내용:range object index out of range

# %%
intList=range(10)
try:
  idx=int(input('숫자를 입력하세요:'))
  print(intList[idx])
except ValueError:
  print('입력한 내용이 숫자가 아닙니다.')
except IndexError as e:
  print(f'인덱스 오류가 발생:{e}')
# Out:
# 숫자를 입력하세요:a
# 입력한 내용이 숫자가 아닙니다.
