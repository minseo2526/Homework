# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/118%20d.values()_119%20reversed(d).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats={'유비':89,'관우':95,'장비':91,'조운':94}
levels=greats.values()
print(list(levels))
# Out:
# [89, 95, 91, 94]

# %%
greats['조운']=97
print(list(levels))
# Out:
# [89, 95, 91, 97]

# %%
greats={'유비':89,'관우':95,'장비':91,'조운':94}
levels=reversed(greats)
print(list(levels))
# Out:
# ['조운', '장비', '관우', '유비']
