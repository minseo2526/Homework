# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/144module_145__init__.py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

filename = 'python.200.study.py'
ret = os.path.splitext(filename)
print(f'파일 이름:{ret[0]}, 파일 확장자:{ret[1]}')
# Out:
# 파일 이름:python.200.study, 파일 확장자:.py
