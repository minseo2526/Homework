# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/98set%20calculation_99set.add().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1=set('abradacabra')
set2=set('abbreviation')

# %%
ret=set1|set2
print(ret)
# Out:
# {'v', 'r', 'o', 'i', 'a', 'e', 'n', 'c', 'd', 'b', 't'}

# %%
ret=set1&set2
print(ret)
# Out:
# {'a', 'b', 'r'}

# %%
ret=set1-set2
print(ret)
# Out:
# {'c', 'd'}

# %%
ret=set1^set2
print(ret)
# Out:
# {'v', 'o', 'i', 'e', 'n', 'c', 'd', 't'}

# %%
ret=set1<=set2
print(ret)
# Out:
# False

# %%
fruits={'사과','배','오렌지','수박'}
fruits.add('딸기')
print(fruits)
# Out:
# {'사과', '수박', '배', '딸기', '오렌지'}

# %%
fruits.add('배')
print(fruits)
# Out:
# {'사과', '수박', '배', '딸기', '오렌지'}
