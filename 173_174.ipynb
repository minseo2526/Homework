# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/173_174.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import localtime,strftime

weekdays=['월요일','화요일','수요일','목요일','금요일','토요일','일요일']
t=localtime()
today=strftime('%Y-%m-%d',t)
print(f'{today}은 {weekdays[t.tm_wday]}입니다.')
# Out:
# 2025-12-19은 금요일입니다.

# %%
import re
p=re.compile(r'href=".*"',re.I)

# %%
contents="""<a href=help.html>도움말을 보려면 여기를 클릭하세요</a><fontsize="15">"""
ret=p.match(contents)
print(ret)
# Out:
# None

# %%
contents2="""href="help.html"도움말을 보려면 여기를 클릭하세요</a><fontsize="15">"""
ret=p.match(contents2)
print(ret.group())
# Out:
# href="help.html"도움말을 보려면 여기를 클릭하세요</a><fontsize="15"

# %%
ret=p.search(contents)
if ret:
    print(f'Match.group()={ret.group()}')
    print(f'Match.start()={ret.start()}')
    print(f'Match.end()={ret.end()}')
    print(f'Match.span()={ret.span()}')
else:
    print('No match found.')
# Out:
# No match found.

# %%
ret=p.findall(contents)
print(ret)
# Out:
# []

# %%
p=re.compile(r'href=".*?"',re.I)

# %%
p=re.compile(r'src=\nS+"',re.I)
with open('webpage.html') as f:
    contents=f.read()

imgurls=p.findall(contents)
for imgurl in imgurls:
      imgurl=imgurl,split('"')[1]
      print
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2226953191.py in <cell line: 0>()
#       1 p=re.compile(r'src=\nS+"',re.I)
# ----> 2 with open('webpage.html') as f:
#       3     contents=f.read()
#       4
#       5 imgurls=p.findall(contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'webpage.html'
