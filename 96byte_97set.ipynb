# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/96byte_97set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bytesData=b'abcdef'
data=bytesData.replace(b'ab',b'AB')
print(data)
# Out:
# b'ABcdef'

# %%
bytesData=b'abcdefabcdef'
idx1=bytesData.find(b'e')
idx2=bytesData.find(b'e',idx1+1)
print(idx1,idx2)
# Out:
# 4 10

# %%
bytesData=b'  abcdef  '
bytesData=bytesData.strip()
print(bytesData)
# Out:
# b'abcdef'

# %%
setData={'사과','배','사과','수박','오렌지'}
print(setData)
# Out:
# {'사과', '수박', '배', '오렌지'}

# %%
print(setData)
# Out:
# {'사과', '수박', '배', '오렌지'}

# %%
strData='abcabccdef'
setData=set(strData)
print(setData)
# Out:
# {'f', 'a', 'e', 'c', 'd', 'b'}

# %%
fruits={'사과','배','사과','수박','오렌지'}
setData=set(fruits)
print(setData)
# Out:
# {'사과', '수박', '배', '오렌지'}
