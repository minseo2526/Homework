# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/126%20global_127%20return.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
param=10
def func1(param):
  localData=5
  print(f'param={param}')
  return

func1(5)
print(f'param={param}')
# Out:
# param=5
# param=10

# %%
param=10
def func2():
  param=20
  return param

ret=func2()
print(f'param={param}')
# Out:
# param=10

# %%
param=10
def func3():
  global param
  param=20
  return

func3()
print(f'param={param}')
# Out:
# param=20

# %%
def reverse(*args):
  result=[]
  idx=len(args)-1
  while idx>=0:
    result.append(args[idx])
    idx-=1
  return result

# %%
ret=reverse('가','나','다','라')
print(ret)
# Out:
# ['라', '다', '나', '가']
