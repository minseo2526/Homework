# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/168_169.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import time
print(f'1970-01-01 00:00:00 이후 지금 현재까지 경과된 초:{time()}')
# Out:
# 1970-01-01 00:00:00 이후 지금 현재까지 경과된 초:1766130446.919077

# %%
def cumalativeSum(n):
    ret=0
    for i in range(1,n+1):
      ret+=i
    return ret

# %%
from time import time
n=10000000
stime=time()
answer=cumalativeSum(n)
etime=time()
print(f'1에서 {n:,}까지 누적합 계산 시간:{(etime-stime):3f}초')
# Out:
# 1에서 10,000,000까지 누적합 계산 시간:0.628460초

# %%
from time import sleep

for i in range(1,6):
    print('*'*i)
    sleep(0.5)
# Out:
# *
# **
# ***
# ****
# *****
