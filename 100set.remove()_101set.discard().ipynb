# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/100set.remove()_101set.discard().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits={'사과','배','오렌지','수박'}
fruits.remove('사과')
print(fruits)
# Out:
# {'수박', '배', '오렌지'}

# %%
fruits.remove('딸기')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-954756110.py in <cell line: 0>()
# ----> 1 fruits.remove('딸기')
#
# KeyError: '딸기'

# %%
fruits={'사과','배','오렌지','수박'}
fruits.discard('사과')
print(fruits)
fruits.discard('딸기')
print(fruits)
# Out:
# {'수박', '배', '오렌지'}
# {'수박', '배', '오렌지'}
