# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/148pip_149__main__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
def printName():
  print(f'module_b의 __name__={__name__}')

# %%
def printName():
  print(f'module_b의 __name__={__name__}')

printName()
print(f'실행 모듈인 이 모듈의 __name__={__name__}')
# Out:
# module_b의 __name__=__main__
# 실행 모듈인 이 모듈의 __name__=__main__
