# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/128%20lambda_129%20annotation%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=lambda x:x**2
print(f(2))
print(f(3))
# Out:
# 4
# 9

# %%
f=lambda x:x+'.txt'
print(f('readme'))
# Out:
# readme.txt

# %%
f=lambda x:x[1]
print(f('readme'))
print(f(('장비',10)))
# Out:
# e
# 10

# %%
def setLevel(character: str, level:int)->dict[str,int]:
  return {character:level}

# %%
def setLevel(character:str,level:int)->None:
  global greats
  greats[character]=level
  return

# %%
greats={'유비':10,'관우':15,'장비':10}
setLevel('유비',13)
print(greats)
# Out:
# {'유비': 13, '관우': 15, '장비': 10}
