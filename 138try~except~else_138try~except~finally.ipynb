# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/138try~except~else_138try~except~finally.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fileList=['file01.jpg','file02.jpg','file03','file04.jpg']
try:
  for file in fileList:
    fname=file.split('.')
    print(f'파일 이름:{fname[0]},파일확장자:{fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 예외 발생')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
# Out:
# 파일 이름:file01,파일확장자:jpg
# 파일 이름:file02,파일확장자:jpg
# ERROR!! <file03> 처리중 예외 발생

# %%
fileList=['file01.jpg','file02.jpg','file03.jpg','file04.jpg']
try:
  for file in fileList:
    fname=file.split('.')
    print(f'파일 이름:{fname[0]},파일확장자:{fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 예외 발생')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
# Out:
# 파일 이름:file01,파일확장자:jpg
# 파일 이름:file02,파일확장자:jpg
# 파일 이름:file03,파일확장자:jpg
# 파일 이름:file04,파일확장자:jpg
# 모든 파일을 성공적으로 처리했습니다.

# %%
fileList=['file01.jpg','file02.jpg','file03','file04.jpg']
try:
  for file in fileList:
    fnmae=file.spllt('.')
    print(f'파일 이름:{fname[0]},파일확장자:{fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 예외 발생')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
finally:
  print('무조건 수행되는 코드!')
# Out:
# ERROR!! <file01.jpg> 처리중 예외 발생
# 무조건 수행되는 코드!
