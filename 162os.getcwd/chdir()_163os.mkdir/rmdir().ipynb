# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/162os.getcwd/chdir()_163os.mkdir/rmdir().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import getcwd

print(f'현재 작업 디렉토리:{getcwd()}')
# Out:
# 현재 작업 디렉토리:/content

# %%
from os import chdir
from os import getcwd

print(f'현재 작업 디렉토리:{getcwd()}')
chdir('..')
print(f'현재 작업 디렉토리:{getcwd()}')
# chdir('c:/mywork/jupyter')  # Windows 경로이므로 Colab에서 오류 발생
print(f'현재 작업 디렉토리:{getcwd()}')
# Out:
# 현재 작업 디렉토리:/
# 현재 작업 디렉토리:/
# 현재 작업 디렉토리:/

# %%
from os import mkdir

folder='myfolder'
mkdir(folder)

# %%
from os import makedirs

folder='/content/myfolder2'
makedirs(folder, exist_ok=True)

# %%
from os import rmdir

folder='myfolder'
folder2='c:/mywork/jupyter/myfolder2'
rmdir(folder)
rmdir(folder2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2356374548.py in <cell line: 0>()
#       3 folder='myfolder'
#       4 folder2='c:/mywork/jupyter/myfolder2'
# ----> 5 rmdir(folder)
#       6 rmdir(folder2)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfolder'
