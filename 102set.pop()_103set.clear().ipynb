# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/102set.pop()_103set.clear().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits={'사과','배','오렌지','수박'}
choise=fruits.pop()
print(f'++추출한 요소:{choise}\n++fruits:{fruits}')
# Out:
# ++추출한 요소:사과
# ++fruits:{'수박', '배', '오렌지'}

# %%
for _ in range(len(fruits)):
  choise=fruits.pop()
  print(f'++추출한 요소:{choise}\n++fruits:{fruits}')
choise=fruits.pop()
# Out:
# ++추출한 요소:수박
# ++fruits:{'배', '오렌지'}
# ++추출한 요소:배
# ++fruits:{'오렌지'}
# ++추출한 요소:오렌지
# ++fruits:set()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3455347276.py in <cell line: 0>()
#       2   choise=fruits.pop()
#       3   print(f'++추출한 요소:{choise}\n++fruits:{fruits}')
# ----> 4 choise=fruits.pop()
#
# KeyError: 'pop from an empty set'

# %%
set1=set('abradacabra')
set2=set('arirangsong')
set1&=set2
set2.clear()
print(f'set1={set1},set2={set2}')
# Out:
# set1={'a', 'r'},set2=set()
