# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/170_171.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import localtime,strftime

time_stamp=strftime("%Y-%m-%d %H:%M:%S", localtime())
print(f'현재시간:{time_stamp}')
# Out:
# 현재시간:2025-12-19 07:54:26

# %%
from time import localtime,strftime

t=localtime()
today=strftime('%Y-%m-%d',t)
print(f'{today}은 {t.tm_year}-01-01 이후 {t.tm_yday}일째 되는 날입니다.')
# Out:
# 2025-12-19은 2025-01-01 이후 353일째 되는 날입니다.
