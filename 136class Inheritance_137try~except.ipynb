# %% [markdown]
# <a href="https://colab.research.google.com/github/minseo2526/Homework/blob/main/136class%20Inheritance_137try~except.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Character:
  def __init__(self):
    self.strength=1
    self.offense_power=1
    self.intelligence=1
    self.mentality=1
    self.agility=1

# %%
class Wizard(Character):
  def setBasic(self,name=None,level=1,hp=100):
    self.name=name
    self.level=level
    self.hp=hp

# %%
player1=Wizard()
player1.setBasic('StormBaby')
print(f'[{player1.name}] 레벨;{player1.level}')
print(f'정신력:{player1.mentality}')
# Out:
# [StormBaby] 레벨;1
# 정신력:1

# %%
class Wizard(Character):
  def __init__(self,name=None):
    self.name=name
    self.level=1
    self.hp=100

# %%
player1=Wizard('StormBaby')
print(f'[{player1.name}] 레벨;{player1.level}')
print(f'정신력:{player1.mentality}')
# Out:
# [StormBaby] 레벨;1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3651575213.py in <cell line: 0>()
#       1 player1=Wizard('StormBaby')
#       2 print(f'[{player1.name}] 레벨;{player1.level}')
# ----> 3 print(f'정신력:{player1.mentality}')
#
# AttributeError: 'Wizard' object has no attribute 'mentality'

# %%
class Wizard(Character):
  def __init__(self,name=None):
    super().__init__()
    self.name=name
    self.level=1
    self.hp=100

# %%
player1=Wizard('StormBaby')
print(f'[{player1.name}] 레벨;{player1.level}')
print(f'정신력:{player1.mentality}')
# Out:
# [StormBaby] 레벨;1
# 정신력:1

# %%
class Parent1:
  def __init__(self):
    print('부모클래스1 생성자')

class Parent2:
  def __init__(self):
    print('부모클래스2 생성자')

class Child(Parent1,Parent2):
  pass
obj= Child()
# Out:
# 부모클래스1 생성자

# %%
fileList=['file01.jpg','file02.jpg','file03.jpg','file04.jpg']
for file in fileList:
  fname=file.split('.')
  print(f'파일 이름:{fname[0]},파일확장자:{fname[1]}')
# Out:
# 파일 이름:file01,파일확장자:jpg
# 파일 이름:file02,파일확장자:jpg
# 파일 이름:file03,파일확장자:jpg
# 파일 이름:file04,파일확장자:jpg

# %%
for file in fileList:
  try:
    fname=file.split('.')
    print(f'파일 이름:{fname[0]},파일확장자:{fname[1]}')
  except:
    print(f'ERROR!! <{file}> 처리중 예외 발생')
# Out:
# 파일 이름:file01,파일확장자:jpg
# 파일 이름:file02,파일확장자:jpg
# 파일 이름:file03,파일확장자:jpg
# 파일 이름:file04,파일확장자:jpg
